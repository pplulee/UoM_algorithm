# %%
from hashset import hashset
import random
import time
import pandas as pd

test_mode=4

def random_string(size=10):
    return ''.join(random.sample(['z','y','x','w','v','u','t','s','r','q','p','o','n','m','l','k','j','i','h','g','f','e','d','c','b','a'], size))
result_insert = []
result_find = []
df =pd.DataFrame(columns=["size","avg_insert","max_insert","avg_find","max_find","collision_rate","time"])

# %%
for i in range(100,100000,100):
    print(i)
    words = []
    for j in range(0,i):
        words.append(random_string())
    test_set = hashset(i*2)
    start = time.time()
    for word in words:
        test_set.insert(word)
    for word in words:
        test_set.find(word)
    end = time.time()
    df.loc[df.index.size]=[i,test_set.get_avg_insert(),test_set.get_max_insert(),test_set.get_avg_find(),test_set.get_max_find(),test_set.get_collision()/test_set.hash_table_size,end-start]
    del words
    del test_set
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
print(len(df))
df.to_csv("hashset_mode4_result.csv")
df
# Out:
# 999
#         size  avg_insert  max_insert  avg_find  max_find  collision_rate  \
# 0      100.0    1.690000         9.0  1.690000       9.0        0.160000
# 1      200.0    1.525000        10.0  1.525000      10.0        0.130000
# 2      300.0    1.443333         7.0  1.443333       7.0        0.145000
# 3      400.0    1.642500        12.0  1.642500      12.0        0.141250
# 4      500.0    1.534000         8.0  1.534000       8.0        0.137000
# ..       ...         ...         ...       ...       ...             ...
# 994  99500.0    1.627608        31.0  1.627608      31.0        0.145678
# 995  99600.0    1.688062        41.0  1.688062      41.0        0.149142
# 996  99700.0    1.588796        32.0  1.588796      32.0        0.141494
# 997  99800.0    1.611232        32.0  1.611232      32.0        0.144795
# 998  99900.0    1.867357        31.0  1.867357      31.0        0.172497
#
#          time
# 0    0.000000
# 1    0.001000
# 2    0.001000
# 3    0.003001
# ...

# %%
df.plot.scatter(x='size',y='time')
df.plot.scatter(x='size',y='avg_find')
df.plot.scatter(x='size',y='avg_insert')
df.plot.scatter(x='size',y='collision_rate')
# Out:
# <AxesSubplot:xlabel='size'>
