# %%
from bstree import bstree
import random
import time
import pandas as pd


def random_string(size=10):
    return ''.join(random.sample(['z','y','x','w','v','u','t','s','r','q','p','o','n','m','l','k','j','i','h','g','f','e','d','c','b','a'], size))
result_insert = []
result_find = []
df =pd.DataFrame(columns=["height","avg_insert","avg_find","time"])

# %%
for i in range(100,100000,100):
    words = []
    for j in range(0,i):
        words.append(random_string())
    test_set = bstree()
    start = time.time()
    for word in words:
        test_set.insert(word)
    for word in words:
        test_set.find(word)
    end = time.time()
    df.loc[df.index.size]=[test_set.height(),test_set.get_insert_stats()/i,test_set.get_find_stats()/i,end-start]
    del words
    del test_set

# %%
print(len(df))
df.to_csv("bstree_result.csv")
df
# Out:
# 999
#      height  avg_insert   avg_find      time
# 0      12.0    6.950000   6.950000  0.000000
# 1      16.0    8.700000   8.700000  0.000000
# 2      15.0    9.163333   9.163333  0.000999
# 3      21.0   11.307500  11.307500  0.002998
# 4      21.0   10.874000  10.874000  0.001998
# ..      ...         ...        ...       ...
# 994    44.0   21.491628  21.491628  1.631459
# 995    39.0   21.064819  21.064819  1.629752
# 996    39.0   21.042588  21.042588  1.636262
# 997    39.0   20.668126  20.668126  1.440455
# 998    41.0   22.423904  22.423904  1.885642
#
# [999 rows x 4 columns]

# %%
df.plot.scatter(x='height',y='time')
df.plot.scatter(x='height',y='avg_find')
df.plot.scatter(x='height',y='avg_insert')
# Out:
# <AxesSubplot:xlabel='height'>
